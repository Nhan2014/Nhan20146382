# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhan2014/Nhan20146382/blob/main/AI_W3_17_02_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load library
import pandas as pd
dataframe=pd.DataFrame()
#add column
dataframe['Name']=['Lemon', 'Apple', 'Banana']
dataframe['Price']=[5, 8,7]
dataframe['License']=[False, True, True]
#show data
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df=dataframe
df.infor
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-3f8b4cf5f199> in <module>
#       1 df=dataframe
# ----> 2 df.infor
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'infor'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
df.loc[(df.Price==5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price==5)|(df.Name=='Banana')]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  Banana      7     True

# %%
df.loc[(df.Price==5)|(df.Name=='Banana'), ['Name','Price']]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.iloc[2]
# Out:
# Name       Banana
# Price           7
# License      True
# Name: 2, dtype: object

# %%
df.loc[[2]]
# Out:
#      Name  Price  License
# 2  Banana      7     True

# %%
df.iloc[0::]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
df.iloc[0:2]
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  Apple      8     True

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum=df.Price.sum()
print(sum)
# Out:
# 20

# %%
max=df.Price.max()
print(max)
# Out:
# 8

# %%
count=df.Price.count()
print(count)
# Out:
# 3

# %%
#create data
new=pd.Series(['Orange',10, True], index=['Name', 'Price', 'License'])
dataframe.append(new, ignore_index=True)
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True
# 3  Orange     10     True

# %%
dataframe['Location']=['USA','Bri','SIN']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True      Bri
# 2  Banana      7     True      SIN

# %%
#delete a row
dataframe.drop(1, axis=0).head(10)
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7     True      SIN

# %%
#delete a column
dataframe.drop('Location', axis=1).head(1)
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
#replace
dataframe['Price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
#rename
dataframe.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True      Bri
# 2  Banana     7     True      SIN

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
dataframe=pd.read_csv(url)

# %%
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
dataframe.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
dt=dataframe
dt.shape
# Out:
# (2311, 8)

# %%
dt.iloc[0:10]
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
dt['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
dt['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
dt.iloc[[200,1]]
# Out:
#      Year        City    Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz   Skiing  Nordic Combined  FIN  individual            M
# 1    1924    Chamonix  Skating   Figure skating  AUT  individual            W
#
#     Medal
# 200  Gold
# 1    Gold
